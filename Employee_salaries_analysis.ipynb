# %%
import pandas as pd
import matplotlib.pyplot as plt 
df = pd.read_csv("ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# Number of people that worked in the year 2020
df2 = df[df["work_year"] == 2020]
df2.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 71
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          72 non-null     int64
#  1   work_year           72 non-null     int64
#  2   experience_level    72 non-null     object
#  3   employment_type     72 non-null     object
#  4   job_title           72 non-null     object
#  5   salary              72 non-null     int64
#  6   salary_currency     72 non-null     object
#  7   salary_in_usd       72 non-null     int64
#  8   employee_residence  72 non-null     object
#  9   remote_ratio        72 non-null     int64
#  10  company_location    72 non-null     object
#  11  company_size        72 non-null     object
# dtypes: int64(5), object(7)
# memory usage: 7.3+ KB

# %%
# Salaries greater than 200000 in the year 2020
df3 = df2[df2['salary_in_usd']>200000]
df3.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 1            1       2020               SE              FT
# 25          25       2020               EX              FT
# 33          33       2020               MI              FT
# 37          37       2020               EN              FT
# 63          63       2020               SE              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 1   Machine Learning Scientist  260000             USD         260000
# 25    Director of Data Science  325000             USD         325000
# 33          Research Scientist  450000             USD         450000
# 37   Machine Learning Engineer  250000             USD         250000
# 63              Data Scientist  412000             USD         412000
#
#    employee_residence  remote_ratio company_location company_size
# 1                  JP             0               JP            S
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 63
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5 non-null      int64
#  1   work_year           5 non-null      int64
#  2   experience_level    5 non-null      object
#  3   employment_type     5 non-null      object
#  4   job_title           5 non-null      object
#  5   salary              5 non-null      int64
#  6   salary_currency     5 non-null      object
#  7   salary_in_usd       5 non-null      int64
#  8   employee_residence  5 non-null      object
#  9   remote_ratio        5 non-null      int64
#  10  company_location    5 non-null      object
#  11  company_size        5 non-null      object
# dtypes: int64(5), object(7)
# memory usage: 520.0+ bytes

# %%
import pandas as pd
df = pd.read_csv("ds_salaries.csv")
df['company_size'] = df['company_size'].replace({'S': 'small','L':'Large', 'M':'medium'})
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE        Large
# 1                 JP             0               JP        small
# ...

# %%
# Company with size is small in 2020
df = df[df['company_size'] == 'small']
df.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 1            1       2020               SE              FT
# 3            3       2020               MI              FT
# 6            6       2020               SE              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 1   Machine Learning Scientist  260000             USD         260000
# 3         Product Data Analyst   20000             USD          20000
# 6          Lead Data Scientist  190000             USD         190000
# 9           Lead Data Engineer  125000             USD         125000
# 10              Data Scientist   45000             EUR          51321
#
#    employee_residence  remote_ratio company_location company_size
# 1                  JP             0               JP        small
# ...

# %%
# Full time employees
df5 = df[df['employment_type'] == 'FT']
df5.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 1            1       2020               SE              FT
# 3            3       2020               MI              FT
# 6            6       2020               SE              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 1   Machine Learning Scientist  260000             USD         260000
# 3         Product Data Analyst   20000             USD          20000
# 6          Lead Data Scientist  190000             USD         190000
# 9           Lead Data Engineer  125000             USD         125000
# 10              Data Scientist   45000             EUR          51321
#
#    employee_residence  remote_ratio company_location company_size
# 1                  JP             0               JP        small
# ...

# %%
df5.count()
# Out:
# Unnamed: 0            77
# work_year             77
# experience_level      77
# employment_type       77
# job_title             77
# salary                77
# salary_currency       77
# salary_in_usd         77
# employee_residence    77
# remote_ratio          77
# company_location      77
# company_size          77
# dtype: int64

# %%
df.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
import matplotlib.pyplot as plt

# Your existing data and plot code
plt.bar(df['employment_type'], df['salary_in_usd'])
plt.xlabel('Employees')
plt.ylabel('Salary in USD')
plt.title('Bar Plot Example')

# Customizations
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines
plt.tight_layout()  # Adjust spacing

# Show the plot
plt.show()

# %%
df['job_title'].value_counts()
#maximum number of data scientist roles where observed
# Out:
# job_title
# Data Scientist                       21
# Machine Learning Engineer            12
# Data Analyst                          8
# Data Engineer                         6
# Lead Data Engineer                    4
# ML Engineer                           4
# Data Science Consultant               3
# AI Scientist                          3
# Machine Learning Scientist            2
# Research Scientist                    2
# BI Data Analyst                       2
# Computer Vision Software Engineer     2
# Computer Vision Engineer              2
# Big Data Engineer                     2
# Product Data Analyst                  1
# Data Engineering Manager              1
# Machine Learning Developer            1
# Cloud Data Engineer                   1
# Director of Data Science              1
# Lead Data Scientist                   1
# Principal Data Scientist              1
# Head of Data Science                  1
# Principal Data Analyst                1
# ...

# %%
data_sc = df[df['job_title'] == 'Data Scientist']
data_sc.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type       job_title  \
# 10          10       2020               EN              FT  Data Scientist
# 40          40       2020               MI              FT  Data Scientist
# 46          46       2020               MI              FT  Data Scientist
# 62          62       2020               EN              PT  Data Scientist
# 65          65       2020               EN              FT  Data Scientist
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 10   45000             EUR          51321                 FR             0
# 40   45760             USD          45760                 PH           100
# 46   60000             GBP          76958                 GB           100
# 62   19000             EUR          21669                 IT            50
# 65   55000             EUR          62726                 DE            50
#
#    company_location company_size
# ...

# %%
# data scientist in small companies whose salary is more than 75000
df6 = data_sc[data_sc['salary'] >75000]
df6.head(15)
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 68           68       2020               EN              FT  Data Scientist
# 69           69       2020               SE              FT  Data Scientist
# 127         127       2021               MI              FT  Data Scientist
# 134         134       2021               EN              FT  Data Scientist
# 143         143       2021               MI              FT  Data Scientist
# 179         179       2021               MI              FT  Data Scientist
# 226         226       2021               SE              FT  Data Scientist
# 251         251       2021               EN              FT  Data Scientist
# 262         262       2021               MI              FT  Data Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 68    105000             USD         105000                 US           100
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 68 to 262
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          9 non-null      int64
#  1   work_year           9 non-null      int64
#  2   experience_level    9 non-null      object
#  3   employment_type     9 non-null      object
#  4   job_title           9 non-null      object
#  5   salary              9 non-null      int64
#  6   salary_currency     9 non-null      object
#  7   salary_in_usd       9 non-null      int64
#  8   employee_residence  9 non-null      object
#  9   remote_ratio        9 non-null      int64
#  10  company_location    9 non-null      object
#  11  company_size        9 non-null      object
# dtypes: int64(5), object(7)
# memory usage: 936.0+ bytes

# %%
import pandas as pd
df = pd.read_csv("ds_salaries.csv")
df['company_size'] = df['company_size'].replace({'S': 'small','L':'Large', 'M':'medium'})
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE        Large
# 1                 JP             0               JP        small
# ...

# %%
# Data scientist in large companies
data_sc = df[df['job_title'] == 'Data Scientist']
data_sc_L = data_sc[data_sc['company_size'] == 'Large']
data_sc_L.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0            0       2020               MI              FT  Data Scientist
# 7            7       2020               MI              FT  Data Scientist
# 11          11       2020               MI              FT  Data Scientist
# 32          32       2020               SE              FT  Data Scientist
# 48          48       2020               MI              FT  Data Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0      70000             EUR          79833                 DE             0
# 7   11000000             HUF          35735                 HU            50
# 11   3000000             INR          40481                 IN             0
# 32     60000             EUR          68428                 GR           100
# 48    105000             USD         105000                 US           100
#
#    company_location company_size
# ...

# %%
# data scientist at large company with experience level MI
data_sc_L_1 = data_sc_L[data_sc_L['experience_level']=='MI']
data_sc_L_1.head()
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0       2020               MI              FT  Data Scientist
# 7             7       2020               MI              FT  Data Scientist
# 11           11       2020               MI              FT  Data Scientist
# 48           48       2020               MI              FT  Data Scientist
# 104         104       2021               MI              FT  Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       70000             EUR          79833                 DE             0
# 7    11000000             HUF          35735                 HU            50
# 11    3000000             INR          40481                 IN             0
# 48     105000             USD         105000                 US           100
# 104     73000             USD          73000                 US             0
#
#     company_location company_size
# ...

# %%
# data scientist at large company with experience level MI and salary less than 100000
data_sc_L3 = data_sc_L_1[data_sc_L_1['salary'] < 100000]
data_sc_L3.head()
# Out:
#      Unnamed: 0  work_year experience_level employment_type       job_title  \
# 0             0       2020               MI              FT  Data Scientist
# 104         104       2021               MI              FT  Data Scientist
# 116         116       2021               MI              FT  Data Scientist
# 152         152       2021               MI              FT  Data Scientist
# 181         181       2021               MI              FT  Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 104   73000             USD          73000                 US             0
# 116   50000             USD          50000                 NG           100
# 152   95000             CAD          75774                 CA           100
# 181   76760             EUR          90734                 DE            50
#
#     company_location company_size
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE        Large
# 1                 JP             0               JP        small
# ...

# %%
df7 = df['job_title'].value_counts()
df7
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# ...
